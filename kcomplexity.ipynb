# %%
import itertools, ast
import warnings
from tqdm.auto import tqdm
warnings.filterwarnings("ignore")

def get_results(alphabet, max_len):
    results = []
    errors = 0
    for L in range(max_len + 1):
        total = len(alphabet) ** L
        for p in tqdm(itertools.product(alphabet, repeat=L), total=total, desc=f"len={L}"):
            s = "".join(p)
            if s.strip() == "":
                continue
            try:
                value = str(eval(s))
            except Exception as e:
                #print(f"Error evaluating '{s}': {e}")
                errors += 1
                continue
            results.append((s, value))
            
    return results, errors
          
alphabet = "0123+-*/()'"
max_len = 7
results, errors = get_results(alphabet, max_len)
print(f"Total results: {len(results)}, errors: {errors}")
# Out:
# len=0: 100%|██████████| 1/1 [00:00<00:00, 14768.68it/s]
# len=1: 100%|██████████| 11/11 [00:00<00:00, 82094.92it/s]
# len=2: 100%|██████████| 121/121 [00:00<00:00, 250128.53it/s]
# len=3: 100%|██████████| 1331/1331 [00:00<00:00, 281098.62it/s]
# len=4: 100%|██████████| 14641/14641 [00:00<00:00, 494558.26it/s]
# len=5: 100%|██████████| 161051/161051 [00:00<00:00, 356930.40it/s]
# len=6: 100%|██████████| 1771561/1771561 [00:03<00:00, 472884.74it/s]
# len=7: 100%|██████████| 19487171/19487171 [00:32<00:00, 594458.66it/s]
# Total results: 571250, errors: 20864637

# %%
def search_results(results, target):
    print("Expressions that evaluate to", target+":")
    count = 0
    shortest = None
    for s, value in results:
        if value == target:
            count += 1
            print(s, "=>", value)
            if shortest is None or len(s) < len(shortest):
                shortest = s
    print("Total found:", count)
    if shortest is not None:
        print(f"Shortest expression is '{shortest}' with length", len(shortest))
               
target = "1000000"
search_results(results, target)
# Out:
# Expressions that evaluate to 1000000:
# 100**3 => 1000000
# 1000000 => 1000000
# 1000**2 => 1000000
# 100**+3 => 1000000
# +100**3 => 1000000
# Total found: 5
# Shortest expression is '100**3' with length 6
