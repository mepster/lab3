# %%
import itertools, ast
import warnings
from tqdm.auto import tqdm
warnings.filterwarnings("ignore")

def get_results(alphabet, max_len):
    results = []
    errors = 0
    for L in range(max_len + 1):
        total = len(alphabet) ** L
        for p in tqdm(itertools.product(alphabet, repeat=L), total=total, desc=f"len={L}"):
            s = "".join(p)
            try:
                value = str(eval(s))
            except Exception as e:
                #print(f"Error evaluating '{s}': {e}")
                errors += 1
                continue
            results.append((s, value))
            
    return results, errors
          
alphabet = "0123+-*/()'"
max_len = 7
results, errors = get_results(alphabet, max_len)
print(f"Total results: {len(results)}, errors: {errors}")

def longest_result(results):
    longest = None
    for s, value in results:
        if longest is None or len(s) > len(longest):
            longest = s
    print("Longest expression is:", longest, "with length", len(longest))

longest_result(results)
# Out:
# len=0: 100%|██████████| 1/1 [00:00<00:00, 24385.49it/s]
# len=1: 100%|██████████| 11/11 [00:00<00:00, 77934.70it/s]
# len=2: 100%|██████████| 121/121 [00:00<00:00, 592886.43it/s]
# len=3: 100%|██████████| 1331/1331 [00:00<00:00, 787060.29it/s]
# len=4: 100%|██████████| 14641/14641 [00:00<00:00, 716120.96it/s]
# len=5: 100%|██████████| 161051/161051 [00:00<00:00, 815303.46it/s]
# len=6: 100%|██████████| 1771561/1771561 [00:02<00:00, 824477.73it/s]
# len=7: 100%|██████████| 19487171/19487171 [00:23<00:00, 826346.79it/s]
# Total results: 571250, errors: 20864638

# %%
def search_results(results, target):
    print("Expressions that evaluate to", target+":")
    count = 0
    shortest = None
    for s, value in results:
        if value == target:
            count += 1
            print(s, "=>", value)
            if shortest is None or len(s) < len(shortest):
                shortest = s
    print("Total found:", count)
    if shortest is not None:
        print(f'Shortest expression is "{shortest}" with length', len(shortest))
               
target = "1000000"
search_results(results, target)

d
# Out:
# Expressions that evaluate to 1000000:
# 100**3 => 1000000
# 1000000 => 1000000
# 1000**2 => 1000000
# 100**+3 => 1000000
# +100**3 => 1000000
# Total found: 5
# Shortest expression is "100**3" with length 6
# Longest expression is: 0000000 with length 7
