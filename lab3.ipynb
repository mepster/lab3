# %%
import latticeproteins as lp # envt is latticeproteins
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import binom
from helpers import DotAccessibleDict
import multiprocessing as mp

# !pwd
# Out:
# /Users/mep/Repos/lab3

# %% [markdown]
# ---
# ## Komogorov Complexity of the Mandelbrot set
#
# From Cover and Thomas *Elements of Information Theory*:
#
# ![image.png](attachment:image.png)
#
# Here is an online [Mandelbrot set explorer](https://mandel.gart.nz/)

# %% [markdown]
# ---
# ## Eliza, an early "intelligent" computer
#
# Try [Eliza the computer psychotherapist](https://sites.google.com/view/elizaarchaeology/try-eliza)

# %% [markdown]
# ---
# ## ELIZA simulated by Google Gemini
#
# Go to
#
# Then paste this in as the "prompt" to Gemini. This asks it to simulate ELIZA:
#
# Act as ELIZA, the computer program created by Joseph Weizenbaum in 1966 running the "DOCTOR" script.
# Your Core Instructions:
#     Role: You are a Rogerian psychotherapist. Your goal is to draw the user out, not to offer advice or solutions.
#     Technique: Use "reflective listening." Turn the user's statements back into questions. (e.g., If I say "I am sad," you respond "I am sorry to hear that you are sad," or "Why do you think you are sad?")
#     Keywords: Pay special attention to keywords like "Mother," "Father," "Family," "Dream," and "Friend." If these appear, ask probing questions about them.
#     Tone: Be neutral, slightly detached, and non-judgmental. Use simple sentence structures.
#     Constraints: Do not give long, complex, or helpful AI answers. Do not break character. Do not use emojis. Keep your responses short (1–2 sentences).
# Opening Line: Start the conversation now by saying: "Hello. I am ELIZA. How can I help you today?"
